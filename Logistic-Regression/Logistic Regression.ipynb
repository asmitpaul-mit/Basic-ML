# %%
import numpy as np
import pandas as pd

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

def startWeights(nFeatures):
    b = np.zeros((nFeatures, 1))
    return b

def CalculateLogLikelihood(X, y, b):
    h = sigmoid(np.dot(X, b))
    likelihood = np.sum(y*np.log(h) + (1 - y)*np.log(1 - h))
    return likelihood

def logisticRegression(X, y, b, learningRate, iterations):
    m = len(y)
    likelihoods = []
    
    for i in range(iterations):
        h = sigmoid(np.dot(X, b))
        gradient = np.dot(X.T, (y - h))/m
        b += learningRate*gradient
        
        likelihood = CalculateLogLikelihood(X, y, b)
        likelihoods.append(likelihood)
        
    return b, likelihoods

# %%
trainData = pd.read_csv('C:\\Users\\ASMITPAUL\\Downloads\\train(1).csv')

# %%
data = pd.DataFrame(trainData)
gender = []

for i in data['Sex']:
    if i == 'male':
        gender.append(1)
    else:
        gender.append(0)

data['Sex'] = gender
data['Bias'] = 1
data
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                             Mr. Owen Harris Braund    1
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...    0
# 2           1       3                              Miss. Laina Heikkinen    0
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle    0
# 4           0       3                            Mr. William Henry Allen    1
# ..        ...     ...                                                ...  ...
# 572         0       3                                Mr. George Patchett    1
# 573         1       2                                Miss. Ethel Garside    0
# 574         1       1           Mrs. William Baird (Alice Munger) Silvey    0
# 575         0       3                    Mrs. Joseph (Maria Elias) Caram    0
# 576         1       3                                 Mr. Eiriik Jussila    1
#
# ...

# %%
XTrain = data[['Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare', 'Bias']]
yTrain = data['Survived'].values.reshape(-1, 1)

b = startWeights(XTrain.shape[1])
learningRate = 0.01
iterations = 10000

b, likelihoods = logisticRegression(XTrain, yTrain, b, learningRate, iterations)
# Out:
# C:\Users\ASMITPAUL\AppData\Local\Temp\ipykernel_4176\3258794626.py:10: RuntimeWarning: divide by zero encountered in log
#   likelihood = np.sum(y*np.log(h) + (1 - y)*np.log(1 - h))
# C:\Users\ASMITPAUL\AppData\Local\Temp\ipykernel_4176\3258794626.py:10: RuntimeWarning: invalid value encountered in multiply
#   likelihood = np.sum(y*np.log(h) + (1 - y)*np.log(1 - h))
# C:\Users\ASMITPAUL\AppData\Local\Temp\ipykernel_4176\3258794626.py:10: RuntimeWarning: divide by zero encountered in log
#   likelihood = np.sum(y*np.log(h) + (1 - y)*np.log(1 - h))
# C:\Users\ASMITPAUL\AppData\Local\Temp\ipykernel_4176\3258794626.py:10: RuntimeWarning: invalid value encountered in multiply
#   likelihood = np.sum(y*np.log(h) + (1 - y)*np.log(1 - h))
# C:\Users\ASMITPAUL\AppData\Local\Temp\ipykernel_4176\3258794626.py:10: RuntimeWarning: divide by zero encountered in log
#   likelihood = np.sum(y*np.log(h) + (1 - y)*np.log(1 - h))
# ...

# %%
testData = pd.read_csv('C:\\Users\\ASMITPAUL\\Downloads\\test(1).csv')
testData
# Out:
#      Survived  Pclass                                               Name  \
# 0           1       2                         Miss. Julie Rachel Christy
# 1           1       1  Mrs. John Borland (Marian Longstreth Morris) T...
# 2           0       2                          Mr. William James Downton
# 3           0       1                                 Mr. John Hugo Ross
# 4           0       3                                 Mr. Uscher Paulner
# ..        ...     ...                                                ...
# 305         0       2                               Rev. Juozas Montvila
# 306         1       1                        Miss. Margaret Edith Graham
# 307         0       3                     Miss. Catherine Helen Johnston
# 308         1       1                               Mr. Karl Howell Behr
# 309         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# ...

# %%
TESTdata = pd.DataFrame(testData)
gender = []

for i in TESTdata['Sex']:
    if i == 'male':
        gender.append(1)
    else:
        gender.append(0)

TESTdata['Sex'] = gender
TESTdata['Bias'] = 1
TESTdata
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           1       2                         Miss. Julie Rachel Christy    0
# 1           1       1  Mrs. John Borland (Marian Longstreth Morris) T...    0
# 2           0       2                          Mr. William James Downton    1
# 3           0       1                                 Mr. John Hugo Ross    1
# 4           0       3                                 Mr. Uscher Paulner    1
# ..        ...     ...                                                ...  ...
# 305         0       2                               Rev. Juozas Montvila    1
# 306         1       1                        Miss. Margaret Edith Graham    0
# 307         0       3                     Miss. Catherine Helen Johnston    0
# 308         1       1                               Mr. Karl Howell Behr    1
# 309         0       3                                 Mr. Patrick Dooley    1
#
# ...

# %%
XTest = TESTdata[['Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare', 'Bias']]
yTest = TESTdata['Survived'].values.reshape(-1, 1)

predictions = sigmoid(np.dot(XTest, b))
binaryPredictions = np.round(predictions)

accuracy = np.mean(binaryPredictions ==  yTest)
print('Accuracy: {}%'.format(accuracy*100))
# Out:
# Accuracy: 77.74193548387098%
